# %%
import pandas as pd
import numpy as np

# %%
enrol = pd.read_csv("../output/tables/enrolment_clean_5states_25districts_2025.csv")
demo  = pd.read_csv("../output/tables/demographic_clean_5states_25districts_2025.csv")
bio   = pd.read_csv("../output/tables/biometric_clean_5states_25districts_2025.csv")

# %%
for df in [enrol, demo, bio]:
    df["date"] = pd.to_datetime(
        df["date"],
        format="mixed",
        dayfirst=True,
        errors="coerce"
    )
    df["month"] = df["date"].dt.to_period("M")

# %%
enrol["date"].isna().sum(), demo["date"].isna().sum(), bio["date"].isna().sum()
# Out:
# (np.int64(0), np.int64(0), np.int64(0))

# %%
enrol_monthly = (
    enrol
    .groupby(["state", "district_final", "pincode", "month"], as_index=False)
    .agg({
        "age_0_5": "sum",
        "age_5_17": "sum",
        "age_18_greater": "sum"
    })
)

# %%
demo_monthly = (
    demo
    .groupby(["state", "district_final", "pincode", "month"], as_index=False)
    .agg({
        "demo_age_5_17": "sum",
        "demo_age_17_": "sum"
    })
)

# %%
bio_monthly = (
    bio
    .groupby(["state", "district_final", "pincode", "month"], as_index=False)
    .agg({
        "bio_age_5_17": "sum",
        "bio_age_17_": "sum"
    })
)

# %%
monthly = (
    enrol_monthly
    .merge(demo_monthly, on=["state", "district_final", "pincode", "month"], how="left")
    .merge(bio_monthly,  on=["state", "district_final", "pincode", "month"], how="left")
)

# %%
monthly[[
    "demo_age_5_17",
    "demo_age_17_",
    "bio_age_5_17",
    "bio_age_17_"
]] = monthly[[
    "demo_age_5_17",
    "demo_age_17_",
    "bio_age_5_17",
    "bio_age_17_"
]].fillna(0)

# %%
monthly["total_demo_updates"] = (
    monthly["demo_age_5_17"] + monthly["demo_age_17_"]
)

monthly["total_bio_updates"] = (
    monthly["bio_age_5_17"] + monthly["bio_age_17_"]
)

# %%
monthly.shape
# Out:
# (5916, 13)

# %%
monthly.head()
# Out:
#           state district_final  pincode    month  age_0_5  age_5_17  \
# 0  chhattisgarh       bilaspur   495001  2025-09      296        44
# 1  chhattisgarh       bilaspur   495001  2025-10      201        26
# 2  chhattisgarh       bilaspur   495001  2025-11      210        49
# 3  chhattisgarh       bilaspur   495001  2025-12      132        12
# 4  chhattisgarh       bilaspur   495004  2025-09       96        10
#
#    age_18_greater  demo_age_5_17  demo_age_17_  bio_age_5_17  bio_age_17_  \
# 0               0          154.0        1664.0         444.0       1236.0
# 1               0          106.0        1479.0        1327.0        929.0
# 2               3          238.0        2426.0        2763.0       2065.0
# 3               1          460.0        3684.0        3509.0       2475.0
# 4               0           51.0         432.0         185.0        424.0
#
#    total_demo_updates  total_bio_updates
# 0              1818.0             1680.0
# 1              1585.0             2256.0
# 2              2664.0             4828.0
# 3              4144.0             5984.0
# 4               483.0              609.0

# %%
monthly_totals = (
    monthly
    .groupby("month", as_index=False)[
        ["total_bio_updates", "total_demo_updates"]
    ]
    .sum()
)

monthly_totals
# Out:
#      month  total_bio_updates  total_demo_updates
# 0  2025-03            10543.0             13606.0
# 1  2025-04            87206.0             54159.0
# 2  2025-05            53469.0             57128.0
# 3  2025-06            43135.0             32220.0
# 4  2025-07           158781.0             95918.0
# 5  2025-09           671973.0            481858.0
# 6  2025-10           402184.0            372973.0
# 7  2025-11           760106.0            838582.0
# 8  2025-12           849166.0            869839.0

# %%
monthly_totals["bio_share"] = (
    monthly_totals["total_bio_updates"] /
    (monthly_totals["total_bio_updates"] + monthly_totals["total_demo_updates"])
)

monthly_totals[["month", "bio_share"]]
# Out:
#      month  bio_share
# 0  2025-03   0.436581
# 1  2025-04   0.616885
# 2  2025-05   0.483458
# 3  2025-06   0.572424
# 4  2025-07   0.623406
# 5  2025-09   0.582384
# 6  2025-10   0.518842
# 7  2025-11   0.475456
# 8  2025-12   0.493987

# %%
active_pincodes = (
    monthly
    .groupby("month")["pincode"]
    .nunique()
    .reset_index(name="active_pincodes")
)

active_pincodes
# Out:
#      month  active_pincodes
# 0  2025-03                5
# 1  2025-04               65
# 2  2025-05               41
# 3  2025-06               29
# 4  2025-07               98
# 5  2025-09             1436
# 6  2025-10             1407
# 7  2025-11             1423
# 8  2025-12             1396

# %%
district_monthly = (
    monthly
    .groupby(["month", "state", "district_final"], as_index=False)
    .agg({
        "total_bio_updates": "sum",
        "total_demo_updates": "sum"
    })
)

# %%
district_monthly.sort_values(
    ["month", "total_bio_updates"],
    ascending=[True, False]
).groupby("month").head(5)
# Out:
#        month          state   district_final  total_bio_updates  \
# 3    2025-03  uttar pradesh     kanpur nagar             2728.0
# 4    2025-03  uttar pradesh          lucknow             2618.0
# 0    2025-03   chhattisgarh           raipur             2616.0
# 1    2025-03    maharashtra            thane             1630.0
# 2    2025-03  uttar pradesh        gorakhpur              951.0
# 10   2025-04    maharashtra            thane            20866.0
# 12   2025-04      rajasthan           jaipur            11203.0
# 18   2025-04  uttar pradesh     kanpur nagar            10987.0
# 19   2025-04  uttar pradesh          lucknow            10598.0
# 13   2025-04      rajasthan          jodhpur             7668.0
# 25   2025-05    maharashtra            thane            15025.0
# 21   2025-05    maharashtra  mumbai suburban             8124.0
# 31   2025-05  uttar pradesh     kanpur nagar             5163.0
# 34   2025-05  uttar pradesh         varanasi             4142.0
# 24   2025-05    maharashtra             pune             4086.0
# 36   2025-06    maharashtra            thane            22891.0
# 37   2025-06      rajasthan          bikaner             4373.0
# 40   2025-06     tamil nadu            salem             3007.0
# 42   2025-06  uttar pradesh     kanpur nagar             3002.0
# 38   2025-06      rajasthan          jodhpur             2944.0
# 52   2025-07    maharashtra            thane            26498.0
# 51   2025-07    maharashtra             pune            22067.0
# 50   2025-07    maharashtra           nashik            17056.0
# 62   2025-07  uttar pradesh         varanasi            14940.0
# 54   2025-07      rajasthan           jaipur            10008.0
# 70   2025-09    maharashtra           nashik            75396.0
# 71   2025-09    maharashtra             pune            64394.0
# 72   2025-09    maharashtra            thane            60207.0
# 74   2025-09      rajasthan           jaipur            49312.0
# 75   2025-09      rajasthan          jodhpur            37437.0
# 97   2025-10    maharashtra            thane            46549.0
# 95   2025-10    maharashtra           nashik            44281.0
# 96   2025-10    maharashtra             pune            39513.0
# 94   2025-10    maharashtra           nagpur            26956.0
# 103  2025-10     tamil nadu          chennai            18501.0
# 120  2025-11    maharashtra           nashik            82603.0
# 122  2025-11    maharashtra            thane            79906.0
# 121  2025-11    maharashtra             pune            69005.0
# 119  2025-11    maharashtra           nagpur            47563.0
# 124  2025-11      rajasthan           jaipur            37108.0
# 146  2025-12    maharashtra             pune            88931.0
# 147  2025-12    maharashtra            thane            81839.0
# 145  2025-12    maharashtra           nashik            71224.0
# 149  2025-12      rajasthan           jaipur            46539.0
# 142  2025-12   chhattisgarh           raipur            41330.0
#
#      total_demo_updates
# 3                4109.0
# 4                2953.0
# 0                2145.0
# 1                2077.0
# 2                2322.0
# 10              11979.0
# 12              12753.0
# 18               4928.0
# 19               4589.0
# 13               3223.0
# 25              21627.0
# 21               6941.0
# 31              12034.0
# 34                  0.0
# 24                  0.0
# 36              26744.0
# 37               2771.0
# 40                  0.0
# 42                  0.0
# 38               2705.0
# 52              24724.0
# 51              12928.0
# 50               6931.0
# 62                  0.0
# 54              13823.0
# 70              19140.0
# 71              37079.0
# 72              36742.0
# 74              25948.0
# 75              13348.0
# 97              44707.0
# 95              30409.0
# 96              44521.0
# 94              19859.0
# 103             15398.0
# 120             98018.0
# 122             99564.0
# 121            114035.0
# 119             44429.0
# 124             38491.0
# 146             97166.0
# 147             83237.0
# 145             47793.0
# 149             48857.0
# 142             18853.0
